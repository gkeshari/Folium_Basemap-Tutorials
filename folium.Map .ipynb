# %%
import folium

m = folium.Map(location = [28.842559, 77.105650], zoom_start = 15)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker(location = [28.842559, 77.105650], popup = "<strong>Delhi</strong>", tooltip = "Dil valon ki Dilli").add_to(m)
folium.Marker(location = [13.074177, 77.546564], popup = "<strong>Bengaluru</strong>", tooltip = "India'sTech Capital", icon = folium.Icon(icon='cloud')).add_to(m)
folium.Marker(location = [25.347872, 82.945535], popup = "<strong>Holy Banaras</strong>", tooltip = "City of Temple & Ghats", icon = folium.Icon(icon='envelope',color='red')).add_to(m)

ur_location = [19.171766, 72.841472]
inhaler_icon = folium.features.CustomIcon("inhaler.jpg", icon_size = (45,45))
folium.Marker(location = ur_location, popup = "<strong>Date : 2 sep 2020, 11A.M. You have taken ur Dose!</strong>", tooltip = "U are Here!", icon = inhaler_icon ).add_to(m)

current_location = [17.843958, 78.694134]
inhaler_icon = folium.features.CustomIcon("inhaler.jpg", icon_size = (45,45))
folium.Marker(location = current_location, popup = "<strong>Date : 3 sep 2020, 3 P.M. You have missed ur Dose!</strong>", tooltip = "U are Here!", icon = inhaler_icon ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
